# %% [markdown]
# Те́нзор — применяемый в математике и физике объект линейной алгебры, заданный на векторном пространстве V конечной размерности n.

# %% [markdown]
# Модель Sequential подходит для простого набора слоев где каждый слой имеет ровно один входной тензор и один выходной тензор.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
